# %%
# Import modules
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../datasets/dataset.csv')
df.head()
# Out:
#    URUT  R101 R101_NAMA  R105  R108  R111  R201  R201A  R201B  R1301A  ...  \
# 0     1    11      Aceh     2     1     1     2      0      2       1  ...
# 1     2    11      Aceh     2     2     1     4      3      1       1  ...
# 2     3    11      Aceh     2     3     1     1      0      1       1  ...
# 3     4    11      Aceh     2     4     1     4      3      1       1  ...
# 4     5    11      Aceh     2     5     1     7      5      2       1  ...
#
#    R1206B  R1207  R1208  R1209  R1210A  R1210B  R1210C  R1210D  R1210E  R1211
# 0       2      1      2      3       2       2       1       1       2      7
# 1       3      1      2      4       1       2       1       1       2      7
# 2       2      1      2      4       2       2       1       2       2      8
# 3       3      2      4      2       2       2       2       1       2      7
# 4       2      4      2      3       1       2       2       1       2      6
#
# [5 rows x 293 columns]

# %%
# drop unnecessary columns
df.drop(['URUT','R101','R101_NAMA','R105','R108','R111','R201','R201A','R201B','B4K1','B4K3','B4K4','B4K5','B4K6','B4K7','LAMA_TINGG','R1501','R1502'], axis=1, inplace=True)
df.shape
# Out:
# (74684, 275)

# %%
# membuat kolom baru dari kolom R605 berdasarkan R601A = 1 atau R605 berdasarkan R601B2 = 2
df['IPUKU'] = np.where(df['R601A'] == 1, df['R605'], df['R601B2'])

# drop kolom R605 dan R601B2
# df = df.drop(['R605', 'R601B2'], axis=1)
df[['R601A', 'IPUKU']].head()
# Out:
#    R601A  IPUKU
# 0      2    6.0
# 1      1    7.0
# 2      2    6.0
# 3      1    7.0
# 4      1    9.0

# %%
df[['R601A', 'IPUKU']].head()
# Out:
#    R601A  IPUKU
# 0      2    6.0
# 1      1    7.0
# 2      2    6.0
# 3      1    7.0
# 4      1    9.0

# %% [markdown]
# Index Kepuasan Hidup Personal
#
# index_khp = (R505 * 18.34 + IPUKU * 21.67 + R610 * 22.81 + R708 * 17.04 + R1211 * 20.14)
#
# Index Kepuasan Hidup Sosial
#
# index_khs = (R802 * 19.41 + R903 * 18.93 + R1005 * 22.13 + R1102 * 20.64 + R1108 * 18.89)
#
# Index Kepuasan Hidup
#
# index_kh = (index_khp * 0.5 + index_khs * 0.5)
#
# Index Perasaan
#
# index_p = (R1302 * 25.86 + R1304 * 36.80 + R1306 * 37.34)
#
# Index Makna Hidup
#
# index_mh = (R1402 * 16.56 + R1404 * 18.44 + R1406 * 15.27 + R1408 * 15.48 + R1410 * 17.48 + R1412 * 16.78)
#
# Index Kebahagiaan
#
# index_k = (index_kh * 0.348 + index_p * 0.3118 + index_mh * 0.3402)

# %%
# Menghitung Index Kepuasan Hidup Personal
df['index_khp'] = round((
    df['R505'] * 0.1834 +
    df['IPUKU'] * 0.2167 +
    df['R610'] * 0.2281 +
    df['R708'] * 0.1704 +
    df['R1211'] * 0.2014
) * 10 , 2)

# Menghitung Index Kepuasan Hidup Sosial
df['index_khs'] = round((
    df['R802'] * 0.1941 +
    df['R903'] * 0.1893 +
    df['R1005'] * 0.2213 +
    df['R1102'] * 0.2064 +
    df['R1108'] * 0.1889
) * 10 , 2)

# Menghitung Index Kepuasan Hidup
df['index_kh'] = round((
    df['index_khp'] * 0.5 +
    df['index_khs'] * 0.5
), 2)

# Menghitung Index Perasaan
df['index_p'] = round((
    df['R1302'] * 0.2586 +
    df['R1304'] * 0.3680 +
    df['R1306'] * 0.3734
) * 10 , 2)

# Menghitung Index Makna Hidup
df['index_mh'] = round((
    df['R1402'] * 0.1656 +
    df['R1404'] * 0.1844 +
    df['R1406'] * 0.1527 +
    df['R1408'] * 0.1548 +
    df['R1410'] * 0.1748 +
    df['R1412'] * 0.1678
) * 10 , 2)

# Menghitung Index Kebahagiaan
df['index_k'] = round((
    df['index_kh'] * 0.348 +
    df['index_p'] * 0.3118 +
    df['index_mh'] * 0.3402
), 2)

# %%
df[['index_khp','index_khs', 'index_kh', 'index_p', 'index_mh', 'index_k']].describe()
# Out:
#           index_khp     index_khs      index_kh       index_p      index_mh  \
# count  74684.000000  74684.000000  74684.000000  74684.000000  74684.000000
# mean      70.455596     80.574794     75.515230     48.485026     73.527213
# std       12.748365      9.200442      9.521549     13.848781     10.414822
# min        6.040000      6.170000     10.000000      0.000000      1.750000
# 25%       63.170000     75.025000     69.840000     39.090000     67.000000
# 50%       71.570000     80.020000     75.810000     47.760000     73.515000
# 75%       78.480000     86.170000     81.350000     57.760000     80.010000
# max      100.000000    100.000000    100.000000    100.000000    100.010000
#
#             index_k
# count  74684.000000
# mean      66.410889
# std        6.940839
# min        9.480000
# 25%       62.160000
# 50%       66.190000
# 75%       70.500000
# max      100.000000

# %%
# drop kolom yang tidak diperlukan
df_selected = df.drop(['R505','R601B2','R605','R610','R708','R1211','R802','R903','R1102','R1108','R1402','R1404','R1406','R1408','R1410','R1412','R1005','R1302','R1304','R1306','IPUKU','index_khp','index_khs', 'index_kh', 'index_p', 'index_mh'], axis=1)

# %%
# Menyimpan hasil perhitungan index kebahagiaan ke dalam file csv
df_selected.to_csv('../datasets/dataset_p1.csv', index=False)
