# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, RobustScaler
from scipy.stats import normaltest
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %%
df=pd.read_csv('../data/dataset_collection.csv')

# %%
df = df.dropna()

# %%
df
# Out:
# Empty DataFrame
# Columns: [URUT, R1301A, R1301B, R1301C, R1303A, R1303B, R1303C, R1305A, R1305B, R1305C, R1305D, R1401A, R1401B, R1401C, R1401D, R1403A, R1403B, R1403C, R1405A, R1405B, R1405C, R1407A, R1407B, R1409A, R1409B, R1411A, R1411B, R1411C, index_k_raw, R1601A, R1601B, R1602, R1603, R1604A, R1604B, R1605A, R1605B, R1605C, R1605D, R1605E, R1606, R1607A, R1607B, R1608A, R1608B, R1608C, R1609A, R1609B1, R1609B2, R1609B3, R1609B4, R1609B5, R1609B6, R1609C, R1610, R1611, R1612, R1613A, R1613B, R1613C, R1614, R1615, R1616, WEIGHT, R501, R502, R503, R504A, R504B, R504C, R601A, R601B1, R602A1, R602A2, R602B, R603, R604A, R604B, R604C, R604D, R604E, R604F, R604G, R606, R607, R608, R609A, R609B, R609C, R701A, R701B, R702A, R702B, R703A1, R703A2, R703B, R704A, R704B, R704C, R704D, ...]
# Index: []
#
# [0 rows x 258 columns]
